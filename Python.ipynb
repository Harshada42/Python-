# %%
#Printing, Debugging, String Manipulation and variables

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World\nI am Py")
# Out:
# Hello World
# I am Py

# %%
print("Hello" + " World")
# Out:
# Hello World

# %%
input("what is your name? ")
# Out:
# what is your name?  py
# 'py'

# %%
print("Hello " + input("Your name?") + "!")
# Out:
# Your name? py
# Hello py!

# %%
name = input("what is your name? ")
print("Hello " + name + "!\nNice to meet you")
# Out:
# what is your name?  py
# Hello py!
# Nice to meet you

# %%
print(len(input("Your Name? ")))
# Out:
# Your Name?  pyk
# 3

# %%
len([42.5,554,23.4])
# Out:
# 3

# %%
print("Welcome to the Band Name Generator.")
city = input("What's the name of the city you grew up in?")
pet = input("What's your pet's name?")
print("Your band name could be " + city + " " + pet)
# Out:
# Welcome to the Band Name Generator.
# What's the name of the city you grew up in? paris
# What's your pet's name? kitty
# Your band name could be paris kitty
