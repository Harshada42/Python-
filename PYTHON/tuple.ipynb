# %%
##Tuple
coordinates = (4,5,2)
print(coordinates)
# Out:
# (4, 5, 2)

# %%
mixed = ("Alice", 32, True, 9.0)
print(mixed)
# Out:
# ('Alice', 32, True, 9.0)

# %%
fruits = ("apple", "banana", "cherry")
print(fruits[0])
print(fruits[-1])
# Out:
# apple
# cherry

# %%
#unpacking a tuple
user = ("john", 30, "engineer")
name, age, profession = user
print(name)
# Out:
# john
